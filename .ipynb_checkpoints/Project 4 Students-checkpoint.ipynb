# %% [markdown]
# # [Computational Social Science] Project 4: Unsupervised Learning
#
# Team members: Shruti, Elizabeth and Hero

# %% [markdown]
# ## Data Description and Preprocessing
#
# For this project, you will explore data from the [National Health and Nutrition Examination Survey](https://www.kaggle.com/cdc/national-health-and-nutrition-examination-survey?select=questionnaire.csv). NHANES is a unique study that combines survey methodology with in-person medical examinations to create a dataset with demographic information, health indicators, and health outcomes.

# %% [markdown]
# We start by importing the data and doing some preliminary preprocessing for you. We import some libraries that will be helpful as well. 'SEQN' is the ID number for each respondent, and 'HSD010' will be our target outcome. [HSD010](https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/HSQ_H.htm#HSD010) asks for the respondent's self reported health condition, which can range from "excellent" to "poor."

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# WARNING: I'm (Hero) having a problem with tensorflow so I have commentted out these two packages but feel free to uncomment
#from keras.models import Sequential
#from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
sns.set_style("darkgrid")
from sklearn.model_selection import train_test_split
from kneed import KneeLocator

# %%
# Load nhanes data
nhanes = pd.read_csv('nhanes.csv')
# Get the ID numbers for each observation (seqn)
seqn = nhanes['SEQN']
# Get the target, "self-reported health condition," HSD010
hsd010 = nhanes['HSD010']
# Drop SEQN and HSD010 from the dataframe and then apply the standard scaler
nhanes = nhanes.drop(['SEQN', 'HSD010'], axis = 1)
nhanes_scaled = pd.DataFrame(StandardScaler().fit_transform(nhanes),
                             columns = nhanes.columns)
# Add the ID and target back in
nhanes_scaled['SEQN'] = seqn
nhanes_scaled['HSD010'] = hsd010
nhanes_scaled = nhanes_scaled.set_index('SEQN')
nhanes_scaled.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ770    OHQ845   PAAQUEX  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ...  0.383802 -0.646584 -0.484200
# 73576 -0.057306  0.128246  0.080373  ...  0.383802 -1.539259 -0.484200
# 73579 -0.057306  0.128246 -0.189513  ...  0.383802 -1.539259  2.065262
# 73581 -0.057306  0.128246  0.080373  ...  0.383802 -0.646584 -0.484200
# 73584 -0.057306  0.128246  0.080373  ... -2.605509  0.246091  2.065262
#
#          SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x  HSD010
# SEQN
# 73568  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440       1
# 73576  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812       1
# 73579 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812       2
# 73581  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440       2
# 73584  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812       3
#
# [5 rows x 242 columns]

# %%
nhanes_scaled.shape
# Out:
# (2064, 242)

# %% [markdown]
# ## Plots

# %% [markdown]
# Let's take a look at the data. Below we visualize boxplots of family income to federal poverty line ratio ('INDFMPIR') and self-reported health condition. Notice how there are some clear patterns (the lower the ratio, the lower reported health condition), but it's not a perfect separation. We have 240+ features in our dataset, and we likely have several features in our dataset that highly correlate with our family income-poverty line ratio measure - PCA will help us simplify these.

# %%
# Create a binary version of hsd010 where 1-3 are "good" and 4-5 are "poor"
nhanes_scaled['HSD010_binary'] = hsd010_binary = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['good', 'good', 'good', 'poor', 'poor']) 
# Recode the original hsd010 with the string labels
nhanes_scaled['HSD010'] = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['excellent', 'very good', 'good', 'fair', 'poor'])
# Boxplot of hsd010
ax = sns.boxplot(x = 'HSD010', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Self-Reported Health Status")
plt.show()

# %%
# Boxplot of hsd010_binary
ax = sns.boxplot(x = 'HSD010_binary', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Binary Self-Reported Health Status")
plt.show()

# %% [markdown]
# Family income also is not necessarily well correlated with measured health outcomes. See below where we look at the relationship between Body Mass Index (BMI) and the family income-poverty line ratio, and shade points by self-reported health condition. It's hard to find a clear pattern - this is where clustering may come in handy.

# %%
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue = "HSD010", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
      ylabel = "Body Mass Index")
ax.set_title("BMI v. Income-Poverty Ratio")
plt.show()

# %% [markdown]
# Before we move to working on unsupervised methods, we'll drop our target variables again:

# %%
nhanes_scaled = nhanes_scaled.drop(['HSD010', 'HSD010_binary'], axis = 1)

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# Conduct a Principal Component Analysis (PCA) of the nhanes data. The data has already been prepared for you, so you can work directly on nhanes_scaled. Be sure to do the following:
#
# - Choose the number of components and provide 1-2 sentences about your choice of the number of components.
# - Plot a barplot of the variation explains by each component.
# - Choose how many components you will use to fit a supervised learning model and provide 1-2 sentences to explain that choice.
# - Plot a 2D scatterplot of the first two components and provide 1-2 sentences analyzing the plot.

# %% [markdown]
# ### Train PCA

# %% [markdown]
# We first train the PCA using 20 components. This is a large enough number that we expect to see a large portion of the variance in the data explained, but not so large that it is hard to visualize. Given that we only have 2000 or so observations, but 240 features, reducing them to 10-20 components would be ideal in order to avoid the curse of dimensionality.

# %%
X = nhanes_scaled
pca = PCA(n_components=20)
pca_nhanes = pca.fit_transform(X)

# %% [markdown]
# ### Decide on the Number of Components
# We plot the share of the variance explained by each of these components below. As you can see from the intersection of the bars with the horizontal line, components 1-16 each explain over 1% of the variation in the data. There is a quick drop off in share explained after component three. Using the 1% explained as a threshold, we could take the first 16 components.

# %%
# make into data frame with component as one variable and explained ratio as another variable 
var_df = pd.DataFrame({"component": np.array(range(1,21)), "var_ratio" : pca.explained_variance_ratio_})

# %%
ax = sns.barplot(x="component", y="var_ratio", data=var_df)
ax.set(xlabel = "Components",
      ylabel = "Share of Variance Explained")
ax.set_title("Variance Ratio Barchart")
ax.axhline(0.01, color = 'r')
plt.show()

# %% [markdown]
# Another way to think about the number of components to take is to consider the total share of the variation explained. We train the PCA to create the maximum number of components and plot the cummulative variation explained against the number of components.

# %%
pca = PCA()
pca_nhanes = pca.fit_transform(X)

# %%
var_df = pd.DataFrame({"component": np.array(range(1,242)), "var_ratio" : pca.explained_variance_ratio_})
# calculate the cummulative variance explained
var_df["cum"] = var_df.cumsum()["var_ratio"]

# %%
ax = sns.scatterplot(x = "component", y = "cum", data = var_df)
ax.set(xlabel = "Number of Components",
      ylabel = "Share of Variation Explained")
ax.set_title("Cummulative Variance Explained")
plt.show()

# %% [markdown]
# The plot above shows that the rate of gain in variation explained starts to fall off pretty quickly (shown by the gradient getting shallower). This is in line with each component after the 16th explaining less than 1% more of the remaining variation. Taking the first 16 components will explain just over 40% of the variation in the data. We think that this is a sufficient share to justify the drastic reduction in dimensions (from 241 to 16).

# %%
#var_df.head(16)

# %%
# finalize the PCA
pca = PCA(n_components = 16)
pca_nhanes = pca.fit_transform(X)
var_df = pd.DataFrame({"component": np.array(range(1,17)), "var_ratio" : pca.explained_variance_ratio_})
var_df["cum"] = var_df.cumsum()["var_ratio"]

# %%
col_names = ["pc" + str(i) for i in range(1,17)]
pca_df = pd.DataFrame(data = pca_nhanes
    , columns = col_names)

# %%
pca_df.head()
# Out:
#         pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0  9.527811 -0.816224 -1.867092 -2.109938 -3.929456 -0.186551 -3.846081
# 1 -5.838339 -3.692573  3.805750 -1.029881  0.394467  1.590937  2.708859
# 2 -0.719454 -2.573200  0.907908 -4.755874 -1.798691  0.863305 -1.024815
# 3  3.533627 -2.576982 -3.249125 -0.405475  3.998913  1.444803 -1.182622
# 4 -6.872094 -4.194241  0.886824 -0.848929 -0.524849  0.073415  0.842385
#
#         pc8       pc9      pc10      pc11      pc12      pc13      pc14  \
# 0 -2.932764  1.513873  0.679125  0.111815  2.233742  0.292993 -0.640773
# 1 -0.736029  0.390797 -2.410028 -0.453407  1.077192  0.512086  2.422501
# 2  0.633713  0.543054  0.455868  0.167943 -1.335934  1.623254 -0.306081
# 3  0.329200 -4.158992 -1.259618 -0.799138  2.068466 -2.183886  2.909052
# 4  0.988152  0.564098 -0.042488 -0.469555 -0.992987 -0.706275 -1.775882
#
#        pc15      pc16
# 0  0.358740 -0.618590
# 1  0.242458 -1.440728
# 2  0.478850 -0.677747
# 3 -1.255170 -1.388576
# 4 -0.201579 -0.142356

# %% [markdown]
# ### 2D Scatterplot of the First Two Components
# Below we plot the first two principle components and group them based on our target variables - first for the 5-class health outcome and then for the binary health outcome.

# %%
# create data frame for plots

nhanes_pca = pca_df
nhanes_pca["HSD010"] = hsd010
# great binary version too 
nhanes_pca['HSD010_binary'] = hsd010_binary = nhanes_pca['HSD010'].replace(
    [1, 2, 3, 4, 5], ['good', 'good', 'good', 'poor', 'poor']) 
# recode the original hsd010 with the string labels
nhanes_pca['HSD010'] = nhanes_pca['HSD010'].replace(
    [1, 2, 3, 4, 5], ['excellent', 'very good', 'good', 'fair', 'poor'])

# %%
#nhanes_pca.head()

# %% [markdown]
# The plot below shows *some* correspondence between the first two components and our target variable. Specifically, those with "excellent" health have a greater loading **(I THINK THIS IS THE WRONG WORD - I WILL ASK IN OHS)** of PC1 relative to PC2. Additionally, those in the "very good" class have a negative loading of both PC1 and PC2, with more variation in PC1. Similarly, those in the "good" class have a negative loading of both PC1 and PC2, but the magnitude is greater for PC1. It seems like those with "fair" or "poor" health have a more positive loading of PC2, relative to PC1. From this we might conclude that the features loading on to PC1 are those that are correlated with higher self-reported health, while the features that load on to PC2 are more associated with lower self-reported health.

# %%
ax = sns.scatterplot(x = "pc1", y = "pc2", hue = "HSD010", palette = "tab10", data = nhanes_pca)
ax.set(xlabel = "Principal Component 1",
      ylabel = "Principal Component 2")
ax.set_title("PCA of NHANES - 5-Scale Indicator of Health")
plt.show()

# %% [markdown]
# We can see if this holds when we look at a coarser division of our observations into just two classes, instead of five. Indeed, those with "good" health are more represented by PC1, while those with "poor" health have a higher loading of PC2. Based on both these plots, we think we can be confident that our first two principal components represent meaningful variation in our data.

# %%
ax = sns.scatterplot(x = "pc1", y = "pc2", hue = "HSD010_binary", palette = "tab10", data = nhanes_pca)
ax.set(xlabel = "Principal Component 1",
      ylabel = "Principal Component 2")
ax.set_title("PCA of NHANES - Binary Indicator of Health")
plt.show()

# %% [markdown]
# ## K-Means

# %% [markdown]
# - Choose a clustering algorithm and explain it in 1-2 sentences.
# - Cluster the nhanes data. Detail any choice you need to make with regards to number of clusters, and how you arrived at that choice. For instance, you might use the [elbow method](https://en.wikipedia.org/wiki/Elbow_method_(clustering) if you choose k-means.
# - Plot your clusters on top of BMI v. Income Poverty Ratio Plot. Describe what you see in 1-2 sentences.
# - Retrain the clustering algorithm, but this time use your PCA results instead of the original dataframe. Plot the clusters on top of the 2D PCA scatterplot from the previous step. Describe your results in 1-2 sentences.

# %% [markdown]
# ### Choose a Clustering Algorithm

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# ### Cluster nhanes

# %%
X = nhanes_scaled

# %%
kmeans = KMeans(init="random", 
                n_clusters=3, 
                n_init=10, 
                max_iter=300, 
                random_state=42)

kmeans.fit(X)

kmeans.inertia_
# Out:
# 431885.2888884454

# %% [markdown]
# The Sum of Standard Errors (SSE) seems really high, so it's likely that 3 is the wrong number of clusters. Given where we wound up with PCA, at 16 components, the number of clusters should probably be larger. To figure out the optimal number, I'll increment k and look at a plot of the SSEs at each level of k.

# %%
kmeans_kwargs = {
    "init": "random", 
    "n_init": 10,
    "max_iter": 300, 
    "random_state": 42,}


sse = []

for k in range(1, 25): 
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs) 
    kmeans.fit(X)
    sse.append(kmeans.inertia_)

# %%
plt.style.use("ggplot")
plt.plot(range(1, 25), sse)
plt.xticks(range(1, 25))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %% [markdown]
# This elbow plot isn't terribly straightforward. We could reasonably defend using 4 or 8 or 16 or 19. Since eyeballing the number is tricky, I'll use a computational method for optimizing k.

# %%
kl = KneeLocator(
    range(1, 25), sse, curve="convex", direction="decreasing"
)
print("The optimal number of k-means clusters is:", kl.elbow,)
print("But I am just a lowly computer with no domain knowledge for this data.")
# Out:
# The optimal number of k-means clusters is: 5
# But I am just a lowly computer with no domain knowledge for this data.

# %% [markdown]
# Looking at the PCA plot, 5 looks like a good number of PCA components, too, though it's hard to grasp substantively what these clusters/components mean.

# %%
kmeans = KMeans(init="random", 
                n_clusters=5, 
                n_init=10, 
                max_iter=300, 
                random_state=42)

kmeans.fit(X)

print("Centers")
print(kmeans.cluster_centers_)
print()

print("Labels")
print(kmeans.labels_)
print()

for point, label in zip(X, kmeans.labels_):
    print("Coordinates:", point, "Label:", label)
    
print(kmeans.n_iter_)
# Out:
# Centers
# [[ 0.         -0.10120862  0.         ...  0.32869766  0.61244043
#    3.42142857]
#  [ 0.          0.02849635  0.         ... -0.05590852 -1.26402647
#    2.5       ]
#  [ 0.          0.04982146  0.         ... -0.21430192  0.26653321
#    2.35854342]
#  [ 0.          0.00657617  0.         ... -0.06266188  0.03474952
#    2.38992042]
#  [ 0.         -0.08515518  0.         ...  0.36697746  0.55885445
#    3.18377088]]
#
# Labels
# [3 1 1 ... 1 3 2]
#
# Coordinates: DR1DRSTZ Label: 3
# Coordinates: DR1EXMER Label: 1
# Coordinates: DRABF Label: 1
# Coordinates: DRDINT Label: 2
# Coordinates: DR1DBIH Label: 1
# Coordinates: DR1DAY Label: 3
# Coordinates: DR1LANG Label: 1
# Coordinates: DR1MNRSP Label: 4
# Coordinates: DR1HELPD Label: 2
# Coordinates: DBQ095Z Label: 2
# Coordinates: DRQSPREP Label: 4
# Coordinates: DR1STY Label: 4
# Coordinates: DRQSDIET Label: 2
# Coordinates: DR1TNUMF Label: 4
# Coordinates: DR1TKCAL Label: 2
# Coordinates: DR1TPROT Label: 0
# Coordinates: DR1TCARB Label: 0
# Coordinates: DR1TSUGR Label: 2
# Coordinates: DR1TFIBE Label: 3
# Coordinates: DR1TTFAT Label: 3
# Coordinates: DR1TSFAT Label: 2
# Coordinates: DR1TMFAT Label: 4
# Coordinates: DR1TPFAT Label: 3
# Coordinates: DR1TCHOL Label: 1
# Coordinates: DR1TATOC Label: 2
# Coordinates: DR1TRET Label: 1
# Coordinates: DR1TVARA Label: 2
# Coordinates: DR1TBCAR Label: 3
# Coordinates: DR1TLZ Label: 3
# Coordinates: DR1TVB1 Label: 4
# Coordinates: DR1TVB2 Label: 0
# Coordinates: DR1TNIAC Label: 2
# Coordinates: DR1TVB6 Label: 3
# Coordinates: DR1TFOLA Label: 4
# Coordinates: DR1TFA Label: 4
# Coordinates: DR1TFF Label: 3
# Coordinates: DR1TFDFE Label: 4
# Coordinates: DR1TCHL Label: 2
# Coordinates: DR1TVB12 Label: 4
# Coordinates: DR1TVC Label: 1
# Coordinates: DR1TVD Label: 4
# Coordinates: DR1TVK Label: 4
# Coordinates: DR1TCALC Label: 2
# Coordinates: DR1TPHOS Label: 4
# Coordinates: DR1TMAGN Label: 1
# Coordinates: DR1TIRON Label: 2
# Coordinates: DR1TZINC Label: 2
# Coordinates: DR1TCOPP Label: 1
# Coordinates: DR1TSODI Label: 2
# Coordinates: DR1TPOTA Label: 2
# Coordinates: DR1TSELE Label: 1
# Coordinates: DR1TMOIS Label: 4
# Coordinates: DR1TS040 Label: 2
# Coordinates: DR1TS060 Label: 0
# Coordinates: DR1TS080 Label: 2
# Coordinates: DR1TS100 Label: 4
# Coordinates: DR1TS120 Label: 2
# Coordinates: DR1TS140 Label: 4
# Coordinates: DR1TS160 Label: 1
# Coordinates: DR1TS180 Label: 0
# Coordinates: DR1TM161 Label: 2
# Coordinates: DR1TM181 Label: 2
# Coordinates: DR1TM201 Label: 3
# Coordinates: DR1TP182 Label: 4
# Coordinates: DR1TP183 Label: 2
# Coordinates: DR1TP204 Label: 4
# Coordinates: DR1.300 Label: 2
# Coordinates: DR1TWS Label: 3
# Coordinates: DRD340 Label: 4
# Coordinates: DRD360 Label: 3
# Coordinates: PEASCST1 Label: 4
# Coordinates: PEASCTM1 Label: 3
# Coordinates: BPXPULS Label: 3
# Coordinates: BMDSTATS Label: 4
# Coordinates: BMXWT Label: 1
# Coordinates: BMXHT Label: 2
# Coordinates: BMXBMI Label: 1
# Coordinates: BMXARML Label: 2
# Coordinates: BMXARMC Label: 4
# Coordinates: BMXWAIST Label: 2
# Coordinates: MGDEXSTS Label: 3
# Coordinates: OHDEXSTS Label: 1
# Coordinates: OHDDESTS Label: 1
# Coordinates: OHX01TC Label: 3
# Coordinates: OHX02TC Label: 1
# Coordinates: OHX03TC Label: 2
# Coordinates: OHX04TC Label: 4
# Coordinates: OHX05TC Label: 2
# Coordinates: OHX06TC Label: 1
# Coordinates: OHX07TC Label: 3
# Coordinates: OHX08TC Label: 1
# Coordinates: OHX09TC Label: 3
# Coordinates: OHX10TC Label: 2
# Coordinates: OHX11TC Label: 3
# Coordinates: OHX12TC Label: 2
# Coordinates: OHX13TC Label: 3
# Coordinates: OHX14TC Label: 4
# Coordinates: OHX15TC Label: 1
# Coordinates: OHX16TC Label: 0
# Coordinates: OHX17TC Label: 3
# Coordinates: OHX18TC Label: 2
# Coordinates: OHX19TC Label: 1
# Coordinates: OHX20TC Label: 0
# Coordinates: OHX21TC Label: 3
# Coordinates: OHX22TC Label: 2
# Coordinates: OHX23TC Label: 2
# Coordinates: OHX24TC Label: 2
# Coordinates: OHX25TC Label: 1
# Coordinates: OHX26TC Label: 1
# Coordinates: OHX27TC Label: 4
# Coordinates: OHX28TC Label: 4
# Coordinates: OHX29TC Label: 3
# Coordinates: OHX30TC Label: 4
# Coordinates: OHX31TC Label: 4
# Coordinates: OHX32TC Label: 4
# Coordinates: URXUMA Label: 2
# Coordinates: URXUMS Label: 4
# Coordinates: URXUCR.x Label: 1
# Coordinates: URXCRS Label: 3
# Coordinates: URDACT Label: 4
# Coordinates: LBXWBCSI Label: 1
# Coordinates: LBXLYPCT Label: 2
# Coordinates: LBXMOPCT Label: 1
# Coordinates: LBXNEPCT Label: 2
# Coordinates: LBXEOPCT Label: 3
# Coordinates: LBXBAPCT Label: 2
# Coordinates: LBDLYMNO Label: 2
# Coordinates: LBDMONO Label: 2
# Coordinates: LBDNENO Label: 2
# Coordinates: LBXRBCSI Label: 2
# Coordinates: LBXHGB Label: 2
# Coordinates: LBXHCT Label: 4
# Coordinates: LBXMCVSI Label: 1
# Coordinates: LBXMCHSI Label: 4
# Coordinates: LBXMC Label: 4
# Coordinates: LBXRDW Label: 1
# Coordinates: LBXPLTSI Label: 3
# Coordinates: LBXMPSI Label: 3
# Coordinates: PHQ020 Label: 2
# Coordinates: PHQ030 Label: 2
# Coordinates: PHQ040 Label: 3
# Coordinates: PHQ050 Label: 2
# Coordinates: PHQ060 Label: 3
# Coordinates: PHAFSTMN.x Label: 2
# Coordinates: LBXHA Label: 1
# Coordinates: LBXHBS Label: 3
# Coordinates: URXVOL1 Label: 2
# Coordinates: SDDSRVYR Label: 1
# Coordinates: RIDSTATR Label: 4
# Coordinates: RIAGENDR Label: 2
# Coordinates: RIDAGEYR Label: 2
# Coordinates: RIDRETH1 Label: 2
# Coordinates: RIDRETH3 Label: 4
# Coordinates: RIDEXMON Label: 2
# Coordinates: DMDBORN4 Label: 1
# Coordinates: DMDCITZN Label: 3
# Coordinates: SIALANG Label: 3
# Coordinates: SIAPROXY Label: 4
# Coordinates: SIAINTRP Label: 4
# Coordinates: FIALANG Label: 2
# Coordinates: FIAPROXY Label: 3
# Coordinates: FIAINTRP Label: 3
# Coordinates: DMDHHSIZ Label: 2
# Coordinates: DMDFMSIZ Label: 3
# Coordinates: DMDHRGND Label: 1
# Coordinates: DMDHRAGE Label: 0
# Coordinates: DMDHRBR4 Label: 2
# Coordinates: DMDHREDU Label: 4
# Coordinates: DMDHRMAR Label: 3
# Coordinates: WTINT2YR Label: 2
# Coordinates: WTMEC2YR Label: 2
# Coordinates: SDMVPSU Label: 2
# Coordinates: SDMVSTRA Label: 2
# Coordinates: INDHHIN2 Label: 2
# Coordinates: INDFMIN2 Label: 2
# Coordinates: INDFMPIR Label: 1
# Coordinates: CBD070 Label: 4
# Coordinates: HSQ500 Label: 2
# Coordinates: HSQ510 Label: 4
# Coordinates: HSQ520 Label: 1
# Coordinates: HSAQUEX Label: 4
# Coordinates: DIQ010 Label: 4
# Coordinates: DIQ050 Label: 1
# Coordinates: DLQ010 Label: 3
# Coordinates: DLQ020 Label: 1
# Coordinates: DLQ040 Label: 3
# Coordinates: DLQ050 Label: 3
# Coordinates: DLQ060 Label: 2
# Coordinates: FSD032A Label: 1
# Coordinates: FSD032B Label: 4
# Coordinates: FSD032C Label: 1
# Coordinates: FSDHH Label: 3
# Coordinates: FSDAD Label: 4
# Coordinates: FSD151 Label: 0
# Coordinates: FSQ165 Label: 2
# Coordinates: FSQ162 Label: 1
# Coordinates: HEQ010 Label: 0
# Coordinates: HEQ030 Label: 1
# Coordinates: HIQ011 Label: 1
# Coordinates: HIQ270 Label: 3
# Coordinates: HIQ210 Label: 4
# Coordinates: HOD050 Label: 2
# Coordinates: HOQ065 Label: 2
# Coordinates: HUQ010 Label: 2
# Coordinates: HUQ020 Label: 2
# Coordinates: HUQ030 Label: 3
# Coordinates: HUQ041 Label: 3
# Coordinates: HUQ071 Label: 2
# Coordinates: HUQ090 Label: 3
# Coordinates: IMQ011 Label: 1
# Coordinates: IMQ020 Label: 4
# Coordinates: INQ020 Label: 1
# Coordinates: INQ012 Label: 2
# Coordinates: INQ030 Label: 1
# Coordinates: INQ060 Label: 4
# Coordinates: INQ080 Label: 2
# Coordinates: INQ090 Label: 3
# Coordinates: INQ132 Label: 3
# Coordinates: INQ140 Label: 4
# Coordinates: INQ150 Label: 4
# Coordinates: IND235 Label: 4
# Coordinates: INDFMMPI Label: 1
# Coordinates: INDFMMPC Label: 3
# Coordinates: MCQ010 Label: 2
# Coordinates: MCQ053 Label: 2
# Coordinates: MCQ082 Label: 4
# Coordinates: MCQ086 Label: 1
# Coordinates: MCQ092 Label: 3
# Coordinates: MCQ203 Label: 2
# Coordinates: MCQ300B Label: 4
# Coordinates: OHQ030 Label: 1
# Coordinates: OHQ033 Label: 2
# Coordinates: OHQ770 Label: 4
# Coordinates: OHQ845 Label: 4
# Coordinates: PAAQUEX Label: 1
# Coordinates: SMQ860 Label: 1
# Coordinates: SMQ870 Label: 2
# Coordinates: SMQ872 Label: 4
# Coordinates: SMQ874 Label: 2
# Coordinates: SMQ878 Label: 1
# Coordinates: SMAQUEX.x Label: 1
# Coordinates: HSD010 Label: 4
# 24

# %% [markdown]
# ### Plot your clusters on top of the BMI v. Income Poverty Ratio Plot

# %%
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue = "HSD010", palette = "colorblind", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
      ylabel = "Body Mass Index")
ax.set_title("BMI v. Income-Poverty Ratio")
# Out:
# Text(0.5, 1.0, 'BMI v. Income-Poverty Ratio')

# %%
# split data into those for each cluster 
zero = np.array([point for label, point in zip(kmeans.labels_, X) if label == 0])
one = np.array([point for label, point in zip(kmeans.labels_, X) if label == 1])
two = np.array([point for label, point in zip(kmeans.labels_, X) if label == 2])
three = np.array([point for label, point in zip(kmeans.labels_, X) if label == 3])
four = np.array([point for label, point in zip(kmeans.labels_, X) if label == 4])

# %%
# plot data with cluster assignment as the color 
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(*zero.T, s=50, c='yellow', label='zero')
#ax1.scatter(*one.T, s=50, c='fuchsia', label='one')
#ax1.scatter(*two.T, s=50, c='chartreuse', label='two')
#ax1.scatter(*three.T, s=50, c='cyan', label='three')
#ax1.scatter(*four.T, s=50, c='b', label='four')

plt.legend(loc='upper left')
plt.show()

# self: come back later and make this work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-2b9fc66873cb> in <module>
#       3 ax1 = fig.add_subplot(111)
#       4
# ----> 5 ax1.scatter(*zero.T, s=50, c='yellow', label='zero')
#       6 #ax2.scatter(*one.T, s=50, c='fuchsia', label='one')
#       7 #ax3.scatter(*two.T, s=50, c='chartreuse', label='two')
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     347     @functools.wraps(func)
#     348     def wrapper(*args, **kwargs):
# --> 349         arguments = func.__signature__.bind(*args, **kwargs).arguments
#     350         # We cannot just check `name not in arguments` because the pyplot
#     351         # wrappers always pass all arguments explicitly.
#
# /opt/anaconda3/lib/python3.8/inspect.py in bind(self, *args, **kwargs)
#    3023         if the passed arguments can not be bound.
#    3024         """
# -> 3025         return self._bind(args, kwargs)
#    3026
#    3027     def bind_partial(self, /, *args, **kwargs):
#
# /opt/anaconda3/lib/python3.8/inspect.py in _bind(self, args, kwargs, partial)
#    2962
#    2963                     if param.name in kwargs and param.kind != _POSITIONAL_ONLY:
# -> 2964                         raise TypeError(
#    2965                             'multiple values for argument {arg!r}'.format(
#    2966                                 arg=param.name)) from None
#
# TypeError: multiple values for argument 's'

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# ### Retrain the clustering algorithm on PCA components and plot clusters on your 2D scatter

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# ## Neural Network

# %% [markdown]
# Now we are ready to predict! Do the following:
#
# - Choose either HSD010 or HSD010\_binary as your target outcome.
# - Train a neural network using the original features. Much of the code to train a basic neural net has been set up for you, but you will need to fill in a couple of missing pieces.
# - Train a neural network using only your PCA components as features.
# - Train a neural network using your PCA components and the predicted class membership from your clustering algorithm as features.
# - Compare and contrast how well each algorithm did. Which featurization technique would you pick and why?

# %% [markdown]
# Below we provide a template for training a neural network. Use this template for training on the original features, on the PCA components, and the PCA components + the predicted classes from your clusters.

# %% [markdown]
# ### Neural Network on Original Features

# %%
y = ... # either hsd010 or hsd010_binary
X = ... # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .25, random_state = 10)

# %%
import keras
num_classes = ...
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(..., ...)
y_test = keras.utils.to_categorical(..., ...)
num_classes = y_test.shape[1]

# %%
model = Sequential()

model.add(
    Dense(..., input_dim= ..., kernel_initializer= ..., activation= ...)
)

model.add(
    Dense(..., kernel_initializer= ..., activation= ...)
)

## Add any additional layers you wish here

model.compile(loss= ..., optimizer= ..., metrics=[...])

model.fit(..., ..., validation_data=(..., ...), epochs=..., batch_size=..., verbose=...)

# %% [markdown]
# ### Neural Network on Principal Components

# %%
## Your Answer Here

# %% [markdown]
# ### Neural Network on Principal Components + Cluster Membership

# %%
## Your Answer Here

# %% [markdown]
# ## Discussion Questions

# %% [markdown]
# 1. In your own words, what is the difference between PCA and clustering?

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# 2. Did you notice any advantages to combining PCA and clustering? If so, what do you think they were? If not, why do you think you didn't see any gains from this combination?

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# 3. How can unsupervised techniques help with downstream supervised learning tasks when working with "big data?"

# %%
## Your Answer Here
